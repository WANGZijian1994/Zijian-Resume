# %%
Header = 'Passionate for NLP, Algorithm and Data Structure, Machine Learning, and Deep Learning'
Name = "ZIJIAN WANG"
Title = 'Master NLP & Data Science & NLP Engineering'
Contact = 'Paris, France\n+33 07 69 22 16 16\nwangzijian1994@hotmail.com\nhttps ://www.linkedin.com/in/wang-zijian-260442165/\nhttps://github.com/WANGZijian1994'
EduHeader = 'EDUCATION'
EduOneTitle = 'Paris Sorbonne University, Master Language and Computer Science'
EduOneTime = '2018-2020'
EduOneDesc = 'Programmation, NLP, Machine Learning, Deep Learning'
EduTwoTitle = 'Paris Sorbonne University, Master Teaching French as foreign language'
EduTwoTime = '2016-2018'
WorkHeader = 'EXPERIENCE'
WorkOneTitle = 'Laboratoire STIH, Sorbonne University / Named Entity Recognition'
WorkOneTime = '05/2020 - present'
WorkOneDesc = '- Use Different Tools NLP to detect Named Entities in German and French.\n- Retrain the Models, evaluate the data, optimise parameters.\n -Github: https ://github.com/WANGZijian1994/Detect-Named-Entity-'
WorkTwoTitle = 'Shanghai Data Exchange Center / Data Scientist and Developer'
WorkTwoTime = '07/2019 - 08/2019'
WorkTwoDesc = '- Database Management with Spring and CURL Database MySQL\n- Software Test\n- Github: https ://github.com/WANGZijian1994/fuxing-tools'
ProjectsHeader = 'IMPORTANT PROJECTS'
ProjectOneTitle = 'Phonetic and Semantic Comparaison (Thesis for Master 1)'
ProjectOneDesc = '- Creation of algorithms to find minimum pairs (phonology).\n- Discovery of French wordnet to find hyponymy and hypernymy\n- Creation of services to search minimum pairs by Spring.\n- Youtube: https://www.youtube.com/watch?v=fQY9d4JoKxE'
ProjectTwoTitle = 'Solr Research'
ProjectTwoDesc = '- Clean data of Ligue 1 French football for 5 years using pandas\n- Annotation and indexation of corpus\n- Creation of services to search by Solr Interface and by Spring'
ProjectThreeTitle = 'Amazon Sentiment analysis'
ProjectThreeDesc = '- Data Scrapy and Data Cleaning Data, using nltk and pandas\n- Vectorization and Word-Embeddings to pre-train data, using sklearn\n- Sentiments Classification using Machine Learning Models\n- 10 "hot topics" using unsupervised learning.'
ProjectFourTitle = 'Speech Recognition'
ProjectFourDesc = '- Collection of phoetic data by Praat and Cleaning Data by Python\n- Training an HMM model to indentify isolated word'
ProjectFiveTitle = 'Algorithmes and Data Structure'
ProjectFiveDesc = "- Participate in offering answers for Leetcode exercices\n- Github: https://github.com/AlgoStudyGroup/Leetcode"
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Pandas\n- NumPy\n- Nltk\n -Spacy\n- Data Visualization\n- Data Cleaning\n -Tensorflow\n -PyTorch\n -selenium\n- Bash\n- Git\n- MySQL\n- neo4j cypher\n- Solr\n- Java\n- Maven and Spring\n- StanfordNLP\n -C++\n -JavaScript\n -HTML CSS'
CertificationsHeader = "Certifications"
CertificationsDesc = "- Coursera SQL for Data Science\n- Coursera C++\n- GRE scores: Verbal 152/170 Quantity 170/170 Writing 4/6"
ExtrasTitle = 'Languages'
ExtrasDesc = '- French level C1\n- English level B2\n- Chinese Mother Tongue \n- Norwegian, German, Spanish, \nand Japanese -Elementary'

import matplotlib.pyplot as plt
# %matplotlib inline

# set font

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5,11))

# Decorative Lines
ax.axvline(x=.5,ymin=0,ymax=1,color='#007ACC',alpha = 0.0,linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text

plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)


plt.annotate(EduHeader, (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.838), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.82), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.04,.80), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.770), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.75), weight='regular', fontsize=9, alpha=.6)


plt.annotate(WorkHeader, (.02,.713), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle, (.02,.692), weight='bold', fontsize=10)

plt.annotate(WorkOneTime, (.02,.678), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkOneDesc, (.04,.631), weight='regular', fontsize=9)

plt.annotate(WorkTwoTitle, (.02,.603), weight='bold', fontsize=10)
plt.annotate(WorkTwoTime, (.02,.589), weight='regular', fontsize=9, alpha=.6)
plt.annotate(WorkTwoDesc, (.03,.543), weight='regular', fontsize=9)



plt.annotate(ProjectsHeader, (.02,.515), weight='bold', fontsize=10, color='#58C1B2')

plt.annotate(ProjectOneTitle, (.02,.490), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.427), weight='regular', fontsize=9)


plt.annotate(ProjectTwoTitle, (.02,.400), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.350), weight='regular', fontsize=9)


plt.annotate(ProjectThreeTitle, (.02,.325), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.264), weight='regular', fontsize=9)

plt.annotate(ProjectFourTitle, (.02,.243), weight='bold', fontsize=10)
plt.annotate(ProjectFourDesc, (.04,.211), weight='regular', fontsize=9)

plt.annotate(ProjectFiveTitle, (.02,.185), weight='bold', fontsize=10)
plt.annotate(ProjectFiveDesc, (.04,.155), weight='regular', fontsize=9)

plt.annotate(CertificationsHeader, (.02,.130), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(CertificationsDesc, (.04,.08), weight='regular', fontsize=9)

plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')

plt.annotate(SkillsHeader, (.7,.850), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.450), weight='regular', fontsize=10, color='#ffffff')

plt.annotate(ExtrasTitle, (.7,.400), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.300), weight='regular', fontsize=10, color='#ffffff')


'''
from matplotlib.offsetbox import TextArea,DrawingArea,OffsetImage,AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread("Zijian WANG CV.png")
imagebox = OffsetImage(arr_code,zoom = 0.5)
ab = AnnotationBbox(imagebox,(0.84,0.12))
ax.add_artist(ab)


'''

plt.savefig("Zijian WANG CV.pdf",dpi = 300,bbox_inches='tight')
